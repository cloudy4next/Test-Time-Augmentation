# %%
from keras.datasets import cifar10, mnist, fashion_mnist
from keras.preprocessing import image
from keras.layers import Conv2D, Dense, Input, Flatten, Dropout
from keras.models import Model, Sequential, load_model
from keras.utils import to_categorical
from keras import optimizers
import keras
from keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import numpy as np
from keras import backend as K
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_val, y_val) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 831s 5us/step

# %%
x_train, x_val = x_train.astype('float32')/255.,  x_val.astype('float32')/255.
y_train, y_val = to_categorical(y_train), to_categorical(y_val)

# %%
train_datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        rotation_range=10.,
        fill_mode='reflect',
        width_shift_range = 0.1, 
        height_shift_range = 0.1)

# %%
train_datagen.fit(x_train)

# %%
plt.figure(figsize=(10,5))

for X_batch, y_batch in train_datagen.flow(x_train, y_train, batch_size=15):
    for i in range(0, 15):
        plt.subplot(3, 5, i+1)
        plt.imshow(X_batch[i].reshape(32, 32, 3), cmap=plt.get_cmap('gray'))
        plt.axis('off')
    plt.tight_layout(pad=0.1)
    plt.show()
    break

# %%
model = Sequential()
model.add(Conv2D(64,(3,3), activation='relu', input_shape=(32,32,3)))
model.add(Conv2D(128,(3,3), activation='relu'))
model.add(Conv2D(128,(3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
bs = 64
epochs = 15

# %%
history = model.fit_generator(train_datagen.flow(x_train, y_train,
                              batch_size=bs),
                              epochs=epochs,
                              steps_per_epoch=len(x_train)/bs,
                              validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From /home/cloudy/anaconda3/envs/compu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/15
# 782/781 [==============================] - 61s 79ms/step - loss: 1.6536 - accuracy: 0.3958 - val_loss: 1.3026 - val_accuracy: 0.5317
# Epoch 2/15
# 782/781 [==============================] - 60s 77ms/step - loss: 1.3096 - accuracy: 0.5334 - val_loss: 1.0993 - val_accuracy: 0.6068
# Epoch 3/15
# 782/781 [==============================] - 76s 97ms/step - loss: 1.1552 - accuracy: 0.5913 - val_loss: 0.9430 - val_accuracy: 0.6702
# Epoch 4/15
# 782/781 [==============================] - 95s 121ms/step - loss: 1.0732 - accuracy: 0.6231 - val_loss: 0.9204 - val_accuracy: 0.6795
# Epoch 5/15
# 782/781 [==============================] - 103s 132ms/step - loss: 1.0117 - accuracy: 0.6466 - val_loss: 0.8561 - val_accuracy: 0.7074
# Epoch 6/15
# 782/781 [==============================] - 110s 141ms/step - loss: 0.9617 - accuracy: 0.6624 - val_loss: 0.8737 - val_accuracy: 0.6952
# Epoch 7/15
# 782/781 [==============================] - 115s 147ms/step - loss: 0.9321 - accuracy: 0.6759 - val_loss: 0.8138 - val_accuracy: 0.7161
# Epoch 8/15
# 782/781 [==============================] - 119s 152ms/step - loss: 0.9038 - accuracy: 0.6866 - val_loss: 0.7579 - val_accuracy: 0.7375
# Epoch 9/15
# 782/781 [==============================] - 123s 157ms/step - loss: 0.8816 - accuracy: 0.6920 - val_loss: 0.7353 - val_accuracy: 0.7448
# Epoch 10/15
# 782/781 [==============================] - 122s 156ms/step - loss: 0.8576 - accuracy: 0.7015 - val_loss: 0.7926 - val_accuracy: 0.7286
# Epoch 11/15
# 782/781 [==============================] - 128s 163ms/step - loss: 0.8411 - accuracy: 0.7062 - val_loss: 0.7560 - val_accuracy: 0.7390
# Epoch 12/15
# 782/781 [==============================] - 128s 164ms/step - loss: 0.8218 - accuracy: 0.7170 - val_loss: 0.7221 - val_accuracy: 0.7507
# Epoch 13/15
# 782/781 [==============================] - 135s 172ms/step - loss: 0.8090 - accuracy: 0.7186 - val_loss: 0.7335 - val_accuracy: 0.7535
# Epoch 14/15
# 782/781 [==============================] - 135s 173ms/step - loss: 0.7965 - accuracy: 0.7250 - val_loss: 0.7195 - val_accuracy: 0.7550
# Epoch 15/15
# 782/781 [==============================] - 132s 168ms/step - loss: 0.7856 - accuracy: 0.7264 - val_loss: 0.6921 - val_accuracy: 0.7650

# %%
print(f'Baseline accuracy: {model.evaluate(x_val, y_val)[1]}')
# Out:
# 10000/10000 [==============================] - 8s 776us/step
# Baseline accuracy: 0.7649999856948853

# %% [markdown]
# ### Define the test Image Generator

# %%
tta_steps = 10

# %%
test_datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        rotation_range=10.,
        fill_mode='reflect', 
        width_shift_range = 0.1, 
        height_shift_range = 0.1)

# %%
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(test_datagen.flow(x_val, batch_size=bs, shuffle=False), steps = len(x_val)/bs)
    predictions.append(preds)
# Out:
# 100%|██████████| 10/10 [01:18<00:00,  7.87s/it]

# %%
final_pred = np.mean(predictions, axis=0)

# %%
print(f'Accuracy with TTA: {np.mean(np.equal(np.argmax(y_val, axis=-1), np.argmax(final_pred, axis=-1)))}')
# Out:
# Accuracy with TTA: 0.7834

# %% [markdown]
# ### See the impact of TTA on a single image

# %%
test_image = x_val[9]
plt.imshow(test_image)
plt.title(f'real label: {np.argmax(y_val[image_ix])}')
plt.axis('off');

# %%
plt.figure(figsize=(20,14))
predictions = []

for i in range(5):
    im = test_datagen.flow(test_image.reshape(1,32,32,3), batch_size=1, shuffle=False)
    im = next(im)
    pred = model.predict(im.reshape(1,32,32,3))
    predictions.append(pred)
    plt.subplot(1, 5, i+1)
    plt.title(f'pred label: {np.argmax(pred)}')
    plt.imshow(im.reshape(32, 32, 3), cmap=plt.get_cmap('gray'))
    plt.axis('off')
plt.show()

# %%
final_pred = np.mean(predictions, axis=0)
print(f'final pred: {np.argmax(final_pred)}')
# Out:
# final pred: 1
